# %% [markdown]
# # Comparisson of GMM with full covariance with implemented models

# %%
import sys
sys.path.append('../')
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_probability as tfp
import utils as utl
import time
import data as d
import models as m
from tqdm import tqdm
from sklearn.mixture import GaussianMixture
tfd = tfp.distributions
tfm = tf.math
# %matplotlib inline

# %% [markdown]
# ### Load data
# In this notebook i load 3 datasets (shown below) and train the following models:
# - GMM with ful covariance (sklearn version)
# - CP-decomposition model
# - Tensor Train model
# <br>
# All models are trained with the same number of components

# %%
N = 10000
data_names = d.get_toy_names()


data1 = d.get_ffjord_data(data_names[0],batch_size=N)
data2 = d.get_ffjord_data(data_names[7],batch_size=N)
data3 = d.get_ffjord_data(data_names[6],batch_size=N)

# Inspect the data
f,ax = plt.subplots(1,3,figsize=(15,5))
ax[0].plot(data1[:, 0], data1[:, 1], '.')
ax[0].axis('equal')
ax[0].set_title(f'8gaussians with {N} points')

ax[1].plot(data2[:, 0], data2[:, 1], '.')
ax[1].axis('equal')
ax[1].set_title(f'checkerboard with {N} points')

ax[2].plot(data3[:, 0], data3[:, 1], '.')
ax[2].axis('equal')
ax[2].set_title(f'2spirals with {N} points')
plt.show()

# Split into batches
batch_size = 100
dataset1 = d.to_tf_dataset(data1, batch_size=batch_size)
dataset2 = d.to_tf_dataset(data2, batch_size=batch_size)
dataset3 = d.to_tf_dataset(data3, batch_size=batch_size)

# %% [markdown]
# ### Define models

# %%
K = 8
M = 2
EPOCHS = 1000

# Define model
model1 = GaussianMixture(n_components=K, covariance_type='full', n_init=5, 
                      tol=1e-6, reg_covar=1e-6, init_params='kmeans')


model2 = m.CPGaussian(K,M,data=data1)
model3 = m.TensorTrainGaussian(K, M, seed = 2)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

# %% [markdown]
# ### Train models 8gaussians dataset
# with $K=8$

# %%
model1.fit(data1)

# Fit the model
losses_CP = []
start_time = time.time()
for epoch in tqdm(range(EPOCHS),desc='Training CP'):  
    loss = model2.train_step(data1,optimizer)
    #loss = 0
    #for i,x in enumerate(dataset1):
    #    loss += model2.train_step(x,optimizer) 
    #losses_CP.append(loss.numpy()/len(dataset1))
    losses_CP.append(loss.numpy())
        
end_time = time.time()
print(f'Training time elapsed: {int(end_time-start_time)} seconds')
print(f'Final loss: {losses_CP[-1]}')



losses_TT = []
start_time = time.time()
for epoch in tqdm(range(EPOCHS),desc='Training TT'):    
    loss = 0
    for i,x in enumerate(dataset1):
        loss += model3.train_step(x,optimizer) 
    losses_TT.append(loss.numpy()/len(dataset1))
        
end_time = time.time()
print(f'Training time elapsed: {int(end_time-start_time)} seconds')
print(f'Final loss: {losses_TT[-1]}')

f,ax = plt.subplots(figsize=(12,5))
ax.plot(losses_CP)
ax.plot(losses_TT)
ax.set_xlabel('Iteration')
ax.set_title('Negative log-likelihood')
ax.legend(['CP-decomposition','Tensor Train model'])
ax.grid('on')
plt.show()
# Out:
# Training CP: 100%|█████████████████████████| 1000/1000 [00:53<00:00, 18.76it/s]
# Training TT:   0%|                                    | 0/1000 [00:00<?, ?it/s]
# Training time elapsed: 53 seconds
# Final loss: 2.8422515392303467
# Training TT: 100%|█████████████████████████| 1000/1000 [01:35<00:00, 10.43it/s]
# Training time elapsed: 95 seconds
# Final loss: 2.834089660644531

# %% [markdown]
# ### Plot the result

# %%
limit = 4
n_points = 1000
alpha = 0.1

x, _ = np.linspace(-limit, limit, n_points,retstep=True)
y, _ = np.linspace(-limit, limit, n_points,retstep=True)
x_grid, y_grid = np.meshgrid(x, y) 
X = np.array([x_grid.ravel(), y_grid.ravel()]).T

# Get the likelihood
p_log = model1.score_samples(X)
p = np.exp(p_log)

f,ax = plt.subplots(1,3,figsize=(16,5))

ax[0].plot(data1[:, 0], data1[:, 1], '.',alpha = alpha)
ax[0].contour(x_grid, y_grid, p.reshape(n_points, n_points))
ax[0].axis('equal')
ax[0].set_title('GMM full cov')
ax[0].set_ylim([-4,4])

utl.plot_contours(ax[1], data1, model2,alpha=0.1)
ax[1].set_title('CP-decomposition')
ax[1].set_ylim([-4,4])

utl.plot_contours(ax[2], data1, model3,alpha=0.1)
ax[2].set_title('Tensor Train')
ax[2].set_ylim([-4,4])

plt.show()
f.savefig('../figures/model_comparison/8gaussians_contour.png',dpi=300,facecolor='w', transparent=False)


f,ax = plt.subplots(1,3,figsize=(16,5))

im = ax[0].imshow(
    p.reshape(n_points, n_points),
    extent=(-limit, limit, -limit, limit),
    origin='lower',
    cmap='hot'
)
cbar = plt.colorbar(im, ax=ax[0])
cbar.ax.set_ylabel('Likelihood')
ax[0].set_title('GMM full cov')

utl.plot_density(ax[1], model2 ,cmap='hot')
ax[1].set_title('CP-decomposition')

utl.plot_density(ax[2], model3 ,cmap='hot')
ax[2].set_title('Tensor Train')
plt.show()
f.savefig('../figures/model_comparison/8gaussians_density.png',dpi=300,facecolor='w', transparent=False)

# %% [markdown]
# # Checkerboard
# Run the same test on the checkerboard dataset with $K=8$

# %%
K = 8
M = 2
EPOCHS = 1000

# Define model
model1 = GaussianMixture(n_components=K, covariance_type='full', n_init=5, 
                      tol=1e-6, reg_covar=1e-6, init_params='kmeans')


model2 = m.CPGaussian(K,M,data=data2)
model3 = m.TensorTrainGaussian(K, M)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

model1.fit(data2)

# Fit the model
losses_CP = []
start_time = time.time()
for epoch in tqdm(range(EPOCHS),desc='Training CP'):    
    loss = model2.train_step(data2,optimizer)
    #loss = 0
    #for i,x in enumerate(dataset1):
    #    loss += model2.train_step(x,optimizer) 
    #losses_CP.append(loss.numpy()/len(dataset1))
    losses_CP.append(loss.numpy())
    
        
end_time = time.time()
print(f'Training time elapsed: {int(end_time-start_time)} seconds')
print(f'Final loss: {losses_CP[-1]}')



losses_TT = []
start_time = time.time()
for epoch in tqdm(range(EPOCHS),desc='Training TT'):    
    loss = 0
    for i,x in enumerate(dataset2):
        loss += model3.train_step(x,optimizer) 
    losses_TT.append(loss.numpy()/len(dataset2))
        
end_time = time.time()
print(f'Training time elapsed: {int(end_time-start_time)} seconds')
print(f'Final loss: {losses_TT[-1]}')

f,ax = plt.subplots(figsize=(12,5))
ax.plot(losses_CP)
ax.plot(losses_TT)
ax.set_xlabel('Iteration')
ax.set_title('Negative log-likelihood')
ax.legend(['CP-decomposition','Tensor Train model'])
ax.grid('on')
plt.show()
# Out:
# Training CP: 100%|█████████████████████████| 1000/1000 [00:53<00:00, 18.83it/s]
# Training TT:   0%|                                    | 0/1000 [00:00<?, ?it/s]
# Training time elapsed: 53 seconds
# Final loss: 3.8136045932769775
# Training TT: 100%|█████████████████████████| 1000/1000 [01:34<00:00, 10.61it/s]
# Training time elapsed: 94 seconds
# Final loss: 3.540091552734375

# %% [markdown]
# ### Plot result

# %%
limit = 4
n_points = 1000
alpha = 0.1

x, _ = np.linspace(-limit, limit, n_points,retstep=True)
y, _ = np.linspace(-limit, limit, n_points,retstep=True)
x_grid, y_grid = np.meshgrid(x, y) 
X = np.array([x_grid.ravel(), y_grid.ravel()]).T

# Get the likelihood
p_log = model1.score_samples(X)
p = np.exp(p_log)

f,ax = plt.subplots(1,3,figsize=(16,5))

ax[0].plot(data2[:, 0], data2[:, 1], '.',alpha = alpha)
ax[0].contour(x_grid, y_grid, p.reshape(n_points, n_points))
ax[0].axis('equal')
ax[0].set_title('GMM full cov')
ax[0].set_ylim([-4,4])

utl.plot_contours(ax[1], data2, model2,alpha=0.1)
ax[1].set_title('CP-decomposition')
ax[1].set_ylim([-4,4])

utl.plot_contours(ax[2], data2, model3,alpha=0.1)
ax[2].set_title('Tensor Train')
ax[2].set_ylim([-4,4])

plt.show()
f.savefig('../figures/model_comparison/checkerboard_contour.png',dpi=300,facecolor='w', transparent=False)


f,ax = plt.subplots(1,3,figsize=(16,5))

im = ax[0].imshow(
    p.reshape(n_points, n_points),
    extent=(-limit, limit, -limit, limit),
    origin='lower',
    cmap='hot'
)
cbar = plt.colorbar(im, ax=ax[0])
cbar.ax.set_ylabel('Likelihood')
ax[0].set_title('GMM full cov')

utl.plot_density(ax[1], model2 ,cmap='hot')
ax[1].set_title('CP-decomposition')

utl.plot_density(ax[2], model3 ,cmap='hot')
ax[2].set_title('Tensor Train')
plt.show()
f.savefig('../figures/model_comparison/checkerboard_density.png',dpi=300,facecolor='w', transparent=False)

# %% [markdown]
# # 2spirals
# Run the same test on the 2spirals dataset with $K=12$

# %%
K = 12
M = 2
EPOCHS = 1000

# Define model
model1 = GaussianMixture(n_components=K, covariance_type='full', n_init=5, 
                      tol=1e-6, reg_covar=1e-6, init_params='kmeans')


model2 = m.CPGaussian(K,M,data=data3)
model3 = m.TensorTrainGaussian(K, M)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

model1.fit(data3)

# Fit the model
losses_CP = []
start_time = time.time()
for epoch in tqdm(range(EPOCHS),desc='Training CP'):    
    loss = model2.train_step(data3,optimizer)
    #loss = 0
    #for i,x in enumerate(dataset1):
    #    loss += model2.train_step(x,optimizer) 
    #losses_CP.append(loss.numpy()/len(dataset1))
    losses_CP.append(loss.numpy())
        
end_time = time.time()
print(f'Training time elapsed: {int(end_time-start_time)} seconds')
print(f'Final loss: {losses_CP[-1]}')



losses_TT = []
start_time = time.time()
for epoch in tqdm(range(EPOCHS),desc='Training TT'):    
    loss = 0
    for i,x in enumerate(dataset3):
        loss += model3.train_step(x,optimizer) 
    losses_TT.append(loss.numpy()/len(dataset3))
        
end_time = time.time()
print(f'Training time elapsed: {int(end_time-start_time)} seconds')
print(f'Final loss: {losses_TT[-1]}')

f,ax = plt.subplots(figsize=(12,5))
ax.plot(losses_CP)
ax.plot(losses_TT)
ax.set_xlabel('Iteration')
ax.set_title('Negative log-likelihood')
ax.legend(['CP-decomposition','Tensor Train model'])
ax.grid('on')
plt.show()
# Out:
# C:\Users\rasmu\Anaconda3\lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Initialization 5 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# Training CP: 100%|█████████████████████████| 1000/1000 [01:20<00:00, 12.48it/s]
# Training TT:   0%|                                    | 0/1000 [00:00<?, ?it/s]
# Training time elapsed: 80 seconds
# Final loss: 3.267345666885376
# Training TT: 100%|█████████████████████████| 1000/1000 [01:46<00:00,  9.40it/s]
# Training time elapsed: 106 seconds
# Final loss: 2.863509521484375

# %%
limit = 4
n_points = 1000
alpha = 0.1

x, _ = np.linspace(-limit, limit, n_points,retstep=True)
y, _ = np.linspace(-limit, limit, n_points,retstep=True)
x_grid, y_grid = np.meshgrid(x, y) 
X = np.array([x_grid.ravel(), y_grid.ravel()]).T

# Get the likelihood
p_log = model1.score_samples(X)
p = np.exp(p_log)

f,ax = plt.subplots(1,3,figsize=(16,5))

ax[0].plot(data3[:, 0], data3[:, 1], '.',alpha = alpha)
ax[0].contour(x_grid, y_grid, p.reshape(n_points, n_points))
ax[0].axis('equal')
ax[0].set_title('GMM full cov')
ax[0].set_ylim([-4,4])

utl.plot_contours(ax[1], data3, model2,alpha=0.1)
ax[1].set_title('CP-decomposition')
ax[1].set_ylim([-4,4])

utl.plot_contours(ax[2], data3, model3,alpha=0.1)
ax[2].set_title('Tensor Train')
ax[2].set_ylim([-4,4])

plt.show()
f.savefig('../figures/model_comparison/2spirals_contour.png',dpi=300,facecolor='w', transparent=False)


f,ax = plt.subplots(1,3,figsize=(16,5))

im = ax[0].imshow(
    p.reshape(n_points, n_points),
    extent=(-limit, limit, -limit, limit),
    origin='lower',
    cmap='hot'
)
cbar = plt.colorbar(im, ax=ax[0])
cbar.ax.set_ylabel('Likelihood')
ax[0].set_title('GMM full cov')

utl.plot_density(ax[1], model2 ,cmap='hot')
ax[1].set_title('CP-decomposition')

utl.plot_density(ax[2], model3 ,cmap='hot')
ax[2].set_title('Tensor Train')
plt.show()
f.savefig('../figures/model_comparison/2spirals_density.png',dpi=300,facecolor='w', transparent=False)
