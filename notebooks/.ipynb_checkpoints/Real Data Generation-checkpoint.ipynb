# %%
import sys
sys.path.append('../')
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_probability as tfp
import utils as utl
import models as m
import datasets as d
tfd = tfp.distributions

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Import real data

# %%
# get possible datasets
dataset_names = d.get_dataset_names()
print(dataset_names)
# Out:
# ['power', 'gas', 'hepmass', 'miniboone', 'bsds300', 'cifar10', 'mnist']

# %% [markdown]
# #### Let's load the gas dataset

# %%
data, X_train, X_val, X_test = d.load_data('gas')

print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (852174, 8)
# (94685, 8)
# (105206, 8)

# %% [markdown]
# #### Let's load the mnist dataset

# %%
data, X_train, X_val, X_test = d.load_data('mnist')

print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (50000, 784)
# (10000, 784)
# (10000, 784)

# %% [markdown]
# How do the images look?

# %%
data.show_images('tst')

# %% [markdown]
# #### Let's load the cifar10 dataset

# %%
data, X_train, X_val, X_test = d.load_data('cifar10')

print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
data.show_images('tst')
# Out:
# (45000, 3072)
# (5000, 3072)
# (10000, 3072)
