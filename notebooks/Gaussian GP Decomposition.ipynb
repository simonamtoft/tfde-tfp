# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import tensorflow as tf
import tensorflow_probability as tfp
tfd = tfp.distributions
tfm = tf.math

# %load_ext autoreload
# %autoreload 2

# %%
# import library functions from repo
import sys, os
sys.path.append('../')

# %% [markdown]
# # Prepare Toy Data

# %%
# Number of datapoints to generate
N = 3000

# %%
# Generate Data
from data import gen_checkerboard as gen_data
data = gen_data(batch_size=N)

# %%
# Inspect the data
plt.plot(data[:, 0], data[:, 1], '.')
plt.axis('equal')
plt.title(f'8gaussians with {N} points')
plt.show()

# %%
# Convert the data to a TF dataset
from data import to_tf_dataset
batch_size = 500
dataset = to_tf_dataset(data, batch_size)

# %%
# Plot a single batch of this dataset
single_batch = list(dataset)[0]
plt.plot(single_batch[:, 0], single_batch[:, 1], '.')
plt.axis('equal')
plt.title(f'8gaussians single batch of size {batch_size}')
plt.show()

# %% [markdown]
# # Initialize Model

# %%
K = 8 # Number of clusters
M = 2 # Number of dimensions

# %%
# init model
from models import CPGaussian
model = CPGaussian(K, M)

# use Adam optimizer
optimizer = tf.keras.optimizers.Adam(lr=1e-3)

# %%
# Initialize means and cov
from sklearn.cluster import KMeans
covs = np.sqrt(np.full((K, M),np.diag(np.cov(data, rowvar = False)))).astype(np.float32)
kmeans = KMeans(n_clusters=K, random_state=0).fit(data)
centroids = kmeans.cluster_centers_
model.initialize(centroids, covs)
# model.trainable_variables

# %% [markdown]
# # Fit model to the data

# %%
# Number of epochs to run the loop
epochs = 1000

# %%
# Fit the model
losses = []
for epoch in range(epochs):
    for data in dataset:
        model.train_step(data, optimizer)
    log_likelihoods = model(data)
    loss = -np.mean(log_likelihoods)
    losses.append(loss)
    if epoch % 20 == 0:
      print("{}/{} mean neg log likelihood: {}".format(epoch+1, epochs, loss))
# Out:
# 1/1000 mean neg log likelihood: 4.702557563781738
# 21/1000 mean neg log likelihood: 4.6262526512146
# 41/1000 mean neg log likelihood: 4.567852973937988
# 61/1000 mean neg log likelihood: 4.545041561126709
# 81/1000 mean neg log likelihood: 4.498693466186523
# 101/1000 mean neg log likelihood: 4.460900783538818
# 121/1000 mean neg log likelihood: 4.470727443695068
# 141/1000 mean neg log likelihood: 4.396792888641357
# 161/1000 mean neg log likelihood: 4.348978519439697
# 181/1000 mean neg log likelihood: 4.289857864379883
# 201/1000 mean neg log likelihood: 4.178005695343018
# 221/1000 mean neg log likelihood: 4.072687149047852
# 241/1000 mean neg log likelihood: 3.952765703201294
# 261/1000 mean neg log likelihood: 3.8981757164001465
# 281/1000 mean neg log likelihood: 3.834052801132202
# 301/1000 mean neg log likelihood: 3.8403987884521484
# 321/1000 mean neg log likelihood: 3.8032689094543457
# 341/1000 mean neg log likelihood: 3.799079656600952
# 361/1000 mean neg log likelihood: 3.7968132495880127
# 381/1000 mean neg log likelihood: 3.7946391105651855
# 401/1000 mean neg log likelihood: 3.785068988800049
# 421/1000 mean neg log likelihood: 3.805418014526367
# 441/1000 mean neg log likelihood: 3.8239707946777344
# 461/1000 mean neg log likelihood: 3.813614845275879
# 481/1000 mean neg log likelihood: 3.83396053314209
# 501/1000 mean neg log likelihood: 3.796783685684204
# 521/1000 mean neg log likelihood: 3.825747489929199
# 541/1000 mean neg log likelihood: 3.8192856311798096
# 561/1000 mean neg log likelihood: 3.827666997909546
# 581/1000 mean neg log likelihood: 3.8057618141174316
# 601/1000 mean neg log likelihood: 3.7757792472839355
# 621/1000 mean neg log likelihood: 3.8054823875427246
# 641/1000 mean neg log likelihood: 3.8121659755706787
# 661/1000 mean neg log likelihood: 3.7776708602905273
# 681/1000 mean neg log likelihood: 3.758329153060913
# 701/1000 mean neg log likelihood: 3.7813150882720947
# 721/1000 mean neg log likelihood: 3.7467174530029297
# 741/1000 mean neg log likelihood: 3.8209662437438965
# 761/1000 mean neg log likelihood: 3.8162593841552734
# 781/1000 mean neg log likelihood: 3.7758560180664062
# 801/1000 mean neg log likelihood: 3.768307685852051
# 821/1000 mean neg log likelihood: 3.7937111854553223
# 841/1000 mean neg log likelihood: 3.8310015201568604
# 861/1000 mean neg log likelihood: 3.841026782989502
# 881/1000 mean neg log likelihood: 3.830028533935547
# 901/1000 mean neg log likelihood: 3.8414254188537598
# 921/1000 mean neg log likelihood: 3.8137850761413574
# 941/1000 mean neg log likelihood: 3.837576389312744
# 961/1000 mean neg log likelihood: 3.8009591102600098
# 981/1000 mean neg log likelihood: 3.789714813232422

# %%
from utils import plot_density, plot_contours
n_points = 1000
limits = 4
plot_density(model, limits, n_points)
plot_contours(data, model, limits, n_points)
